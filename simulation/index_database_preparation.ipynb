# %%
import pyterrier as pt
import gdown
import zipfile
import ir_datasets
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
from db_utils import Base
import os

# %%
if not pt.started():
  pt.init()
# Out:
# PyTerrier 0.9.2 has loaded Terrier 5.7 (built by craigm on 2022-11-10 18:30) and terrier-helper 0.0.7
#
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.

# %%
# !pwd
# Out:
# /

# %%
url = "https://drive.google.com/file/d/16j6dzHIVxlULuIExZl8aJyconEbC7zs4/view?usp=sharing"
output = "/root/.ir_datasets/wapo/WashingtonPost.v2.tar.gz"
#gdown.download(url, output, quiet=False, fuzzy=True)

download_docstore = True

if download_docstore:
  url = "https://drive.google.com/file/d/1LPXK1shthTm-_yH4aA0SQJ0jU_btRPvh/view?usp=sharing"
  output = "WashingtonPost.v2.tar.gz.pklz4.zip"
  #gdown.download(url, output, quiet=False, fuzzy=True)

  #with zipfile.ZipFile(output,"r") as zip_ref:
  #    zip_ref.extractall("/root/.ir_datasets/wapo/")

dataset = ir_datasets.load("wapo/v2")
#indexer = pt.IterDictIndexer('/workspace/indices/wapo_v2', meta={"docno": 36})
#index_ref = indexer.index(dataset.get_corpus_iter(), fields=['url', 'title', 'author', 'kicker', 'body'])

# %%
#now build database

# %%
#! createdb -h postgres wapo

# %%
conn_string = 'postgresql://root@postgres:5432/' + "wapo"
engine = create_engine(conn_string)

# %%
def recreate_database():
    Base.metadata.drop_all(engine)
    Base.metadata.create_all(engine)

#recreate_database()

# %%
Session = sessionmaker(bind=engine)
session = Session()

# %%
from db_utils import parse_wapo_entry
from db_utils import WapoEntry
from db_utils import get_wapo_entry

# %%
cnt = 0

for doc in dataset.docs_iter():
    wapo_entry = parse_wapo_entry(doc)
    session.add(WapoEntry(**wapo_entry))
    cnt+=1
    if cnt % 1000 == 0:
        session.commit()
        print(f"\r {cnt} \t", end="")
session.commit()
# Out:
#  595000

# %%
#prepare topics and qrels

# %%
dataset = pt.get_dataset('irds:wapo/v2/trec-core-2018')

# %%
total_words = 0

cnt = 0
for doc in dataset.get_corpus_iter():
    total_words += len(doc['body'].split(" "))
# Out:
# wapo/v2/trec-core-2018 documents: 100%|██████████| 595037/595037 [00:27<00:00, 21415.00it/s]

# %%
total_words/595037
# Out:
# 475.7733922428353

# %%
#transform topics/qrels

qrels = dataset.get_qrels()
topics = dataset.get_topics()
# Out:
# There are multiple query fields available: ('title', 'description', 'narrative'). To use with pyterrier, provide variant or modify dataframe to add query column.

# %%
topics
# Out:
#     qid                               title  \
# 0   321                Women in Parliaments
# 1   336                  Black Bear Attacks
# 2   341                    Airport Security
# 3   347                 Wildlife Extinction
# 4   350       Health and Computer Terminals
# 5   362                     human smuggling
# 6   363     transportation tunnel disasters
# 7   367                              piracy
# 8   375                     hydrogen energy
# 9   378                     euro opposition
# 10  393                       mercy killing
# 11  397                  automobile recalls
# 12  400                  Amazon rain forest
# 13  408                     tropical storms
# 14  414                Cuba, sugar, exports
# 15  422                 art, stolen, forged
# 16  426               law enforcement, dogs
# 17  427                     UV damage, eyes
# 18  433         Greek, philosophy, stoicism
# 19  439  inventions, scientific discoveries
# 20  442                         heroic acts
# 21  445                        women clergy
# 22  626                      human stampede
# 23  646                food stamps increase
# 24  690         college education advantage
# 25  801            Africa polio vaccination
# 26  802       women driving in Saudi Arabia
# 27  803      declining middle class in U.S.
# 28  804                      "Women on 20s"
# 29  805             eating invasive species
# 30  806      computers and paralyzed people
# 31  807    Chavez medical treatment in Cuba
# 32  808     Boston marathon bombing verdict
# 33  809        protect Earth from asteroids
# 34  810        diabetes and toxic chemicals
# 35  811                         car hacking
# 36  812       social media and teen suicide
# 37  813                   marijuana potency
# 38  814              China one-child impact
# 39  815    Jason Rezaian released from Iran
# 40  816       federal minimum wage increase
# 41  817         Alan Gross released by Cuba
# 42  818              eggs in a healthy diet
# 43  819               U.S. age demographics
# 44  820  bacterial infection mortality rate
# 45  821                         email scams
# 46  822                    Sony cyberattack
# 47  823                     control of MRSA
# 48  824     Bezos purchases Washington Post
# 49  825             ethanol and food prices
#
#                                           description  \
# 0   Pertinent documents will reflect the fact that...
# 1   A relevant document would discuss the frequenc...
# 2   A relevant document would discuss the effectiv...
# 3   The spotted owl episode in America highlighted...
# 4   Is it hazardous to the health of individuals t...
# 5              Identify incidents of human smuggling.
# 6   What disasters have occurred in tunnels used f...
# 7   What modern instances have there been of old f...
# 8   What is the status of research on hydrogen as ...
# 9   Identify documents that discuss opposition to ...
# 10    Identify documents that discuss mercy killings.
# 11  Identify documents that discuss the reasons fo...
# 12  What measures are being taken by local South A...
# 13  What tropical storms (hurricanes and typhoons)...
# 14  How much sugar does Cuba export and which coun...
# 15  What incidents have there been of stolen or fo...
# 16  Provide information on the use of dogs worldwi...
# 17  Find documents that discuss the damage ultravi...
# 18  Is there contemporary interest in the Greek ph...
# 19  What new inventions or scientific discoveries ...
# 20  Find accounts of selfless heroic acts by indiv...
# 21  What other countries besides the United States...
# 22  Find reports of human stampedes that have resu...
# 23  Find documents that discuss an increase in the...
# 24  Find documents which describe an advantage in ...
# 25  Find documents that describe religious objecti...
# 26  Find documents that include expressions of sup...
# 27  Identify the reasons for the decline of the mi...
# 28  Find descriptions of the "Women on 20s" campai...
# 29  Would eating invasive species be a viable meth...
# 30  How can computer technology improve the life o...
# 31  Find documents that describe the medical treat...
# 32  Find documents that contain the verdict reache...
# 33  What efforts are underway to protect Earth fro...
# 34  Is there a link between toxic chemical exposur...
# 35  Find documents that discuss how vulnerable car...
# 36  Find documents detailing the use of social med...
# 37  Find documents that describe differences in ma...
# 38  What has been the long-term impact of China's ...
# 39  Find documents that discuss Washington Post jo...
# 40  Find descriptions of the actions and reactions...
# 41  Find details of the prisoner exchange between ...
# 42  Find documents that support using eggs in a he...
# 43  Find reports of age demographics in the U.S.: ...
# 44  Identify documents that specify the mortality ...
# 45  Find reports of email scams that have defraude...
# 46  Find documents that identify the specific grou...
# 47  Identify documents that describe means of cont...
# 48  Find documents describing reactions to the pur...
# 49  Does diversion of U.S. corn crops into ethanol...
#
#                                             narrative
# 0   Pertinent documents relating to this issue wil...
# 1   It has been reported that food or cosmetics so...
# 2   A relevant document would contain reports on w...
# 3   A relevant item will specify the country, the ...
# 4   Relevant documents would contain any informati...
# 5   A relevant document shows an incident of human...
# 6   A relevant document identifies a disaster in a...
# 7   Documents discussing piracy on any body of wat...
# 8   A relevant document will describe progress in ...
# 9   A relevant document should include the countri...
# 10  All individual cases of mercy killing are rele...
# 11  A relevant document will specify major or mino...
# 12  Relevant documents may identify: the official ...
# 13  The date of the storm, the area affected, and ...
# 14  A relevant document will provide information r...
# 15  Instances of stolen or forged art in any media...
# 16  Relevant items include specific information on...
# 17  A relevant document will discuss diseases that...
# 18  Actual references to the philosophy or philoso...
# 19  The word "new" in the description is defined a...
# 20  Relevant documents will contain a description ...
# 21  To be relevant, a document must indicate eithe...
# 22  Documents that mention people being killed by ...
# 23  Documents that discuss changes in the law allo...
# 24  Relevant documents cite some advantage of a co...
# 25  Religious beliefs have caused some groups in A...
# 26  Relevant documents describe protests against t...
# 27  Relevant documents must identify one or more s...
# 28  Relevant documents describe the "Women on 20s"...
# 29  Relevant documents identify invasive species i...
# 30  Relevant documents describe ways in which comp...
# 31  Relevant documents contain information about w...
# 32  To be relevant, a document must explicitly men...
# 33  Relevant documents will describe real-life eff...
# 34  Identify documents that discuss a link between...
# 35  Relevant documents discuss ways in which cars ...
# 36  A relevant document must give a full account o...
# 37  A relevant document compares or highlights the...
# 38  Relevant documents will contain discussion of ...
# 39  Relevant documents include those that mention ...
# 40  Relevant documents include descriptions of adv...
# 41  Alan Gross, a USAID contractor imprisoned in C...
# 42  A relevant document contains statements that e...
# 43  A relevant document contains specific age demo...
# 44  A relevant document will identify the mortalit...
# 45  A relevant document will describe an instance ...
# 46  Relevant documents must identify the specific ...
# 47  A relevant document will specify a physical or...
# 48  Relevant documents will include news about and...
# 49  Identify documents that discuss the impact of ...

# %%
#cnt, 1, topic, query
qid_map = {}

with open("./workspace/data/wapo/title_queries", "w") as f:
    for i, row in topics.iterrows():
        qid_map[row['qid']] = i+1
        f.write(f"{1},1,{i+1},{row['title']}\n")

# %%
# generate term set

# %%
def generate_100_naive_queries(title, term_set):
    naive_queries = [title]
    
    while len(naive_queries) < 100:
        #draw new term
        for t in term_set:
            new_q =  f"{title} {t}"
            if not new_q in naive_queries:
                naive_queries.append(new_q)
            
            if len(naive_queries) >= 100:
                break
        
        if len(naive_queries) >= 100:
                break

        #draw two terms
        for i,j in [(i, j) for i in range(len(term_set)) for j in range(len(term_set))]:
            
            new_q = f"{title} {term_set[i]} {term_set[j]}"
            if not new_q in naive_queries:
                naive_queries.append(new_q)
            
            if len(naive_queries) >= 100:
                break

        if len(naive_queries) >= 100:
                break

    
    return naive_queries

# %%
term_set = list(set(topics.iloc[0]['description'].split(' ') + topics.iloc[0]['narrative'].split(' ')))
generate_100_naive_queries(topics.iloc[0]['title'], term_set)

# %%
#cnt, 1, topic, query
# generate new 100 queries from narrative and desscription
qid_map = {}



with open("./workspace/data/wapo/title_queries_naive_100", "w") as f:
    for i, row in topics.iterrows():
        qid_map[row['qid']] = i+1

        term_set = " ".join(list(set(row['description'].split(' ') + row['narrative'].split(' ')))).replace(",", " ").replace(".", " ").split(" ")

        naive_100 = generate_100_naive_queries(row['title'], term_set)

        for j in range(100):
            f.write(f"{j+1},1,{i+1},{naive_100[j]}\n")

# %%
#create topic files
for i, row in topics.iterrows():
    with open(f"./workspace/data/wapo/topics/topic.{i+1}", "w") as f:
        f.write(row['title'])

# %%
#topic 0 docno label 
with open("./workspace/data/wapo/wapo_qrels", "w") as f:
    for i, row in qrels.iterrows():
        f.write(f"{qid_map[row['qid']]} 0 {row['docno']} {row['label']}\n")
